# %% [markdown]
# # HelpDeskRAG: Data Exploration
# This notebook profiles the checked-in CSV and records data quality constraints before retrieval design.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / 'src'))
from helpdesk_rag.config import settings
from helpdesk_rag.data_loader import load_dataset, profile_dataset
frame = load_dataset(settings.data_path)
profile_dataset(frame)

# %%
frame.head()
frame['topic'].value_counts()
frame['text'].str.len().describe()
