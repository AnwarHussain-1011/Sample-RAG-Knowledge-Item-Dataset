# %% [markdown]
# # Baseline RAG
# Build the reusable pipeline, run a real dataset question, and inspect sources and latency.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / 'src'))
from helpdesk_rag.config import settings
from helpdesk_rag.pipeline import RAGPipeline
pipeline = RAGPipeline.from_csv(settings.data_path)
pipeline.query('Question 17', top_k=5)
